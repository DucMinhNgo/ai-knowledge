# %% [markdown]
# # Tìm hiểu thuật giải di truyền
# https://viblo.asia/p/thuat-toan-di-truyen-ung-dung-giai-mot-so-bai-toan-kinh-dien-phan-1-RQqKLxJzK7z
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# # Slide giải thuật di truyền
# - Mã hóa nhiếm sắc thể
# - Tùy vào bài toán mà ta có các cách mã hóa khác nhau.
#   + nhị phân
#   + q phân
#   + thứ tự
#   + theo giá trị
#   + dạng cây

# %% [markdown]
# # Paper giải thuật di truyền
# Adaptive Genetic Algorithm Based on Individual Similarity to Solve Multi-Objective Flexible Job-Shop Scheduling Problem:
