# %% [markdown]
# # Hệ thống phân tán (Distributed system):
# Technical architect: Distributed systems.
#
# >> Go (Lập trình song song, lập trình phân tán)
# - 5 individual labs (60%):
# - Final oral exam (40%):
# - Bonus points (up to 20%):

# %% [markdown]
# What is a distributed system?
# Đối với người dùng tiếp xúc với hệ thống phần mềm (bên trong gồm nhiều máy liên kết với nhau trên môi trường mạng):
# - Fault Tolerance (chịu lỗi) hệ thống luôn luôn chạy (24/7).
# - Unlimited Storage: Lưu trữ không giới hạn.
# - Luôn phản hồi.
# - Bảo mật.
#
# Làm thế nào để hệ thống ko bao h chết: có rất nhiều máy phản hồi.
# Làm thế nào để xử lý trong trường hợp kết nối fail.
#
# Xây dựng hệ thống cho mạng như thế nào?
# - chết hoàn toàn
# - chập chờn
# - thay đổi dữ liệu.
#
# Network Partition: Mạng bị phân mảng.
#
# Tất cả đồng hồ trên từng máy phải được đồng bộ hoá với nhau (How).
# Làm sao để chuyển dữ liệu giữa các node với nhau.
#
# What -> Why -> How - When -> Where.
# consistency: nhất quán.
# eventual consistency: nhất quán sau 1 thời điểm.
# inconsistency: không nhất quán.
#
# đồng thuận (chọn xem máy nào phản hồi):

# %% [markdown]
# ![image.png](attachment:image.png)
