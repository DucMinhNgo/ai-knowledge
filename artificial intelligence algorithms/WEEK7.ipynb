# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Fully Observable: No
# Deterministic (có biết trước kết quả ko, nếu có random thì no): Yes
# Episodic (sequential at the level of actions): No
# Static (Wumpus and Pits do not move): Yes
# Discrete: Yes
# Single-agent: Yes

# %% [markdown]
# Logics in general
# Entailment (suy dẫn): nếu A đúng => B đúng ta có kết luận A suy dẫn (Entailment) được B.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Propositional logic (logic mệnh đề)
#
# Model-checking approach (Inference by enumeration): vét cạn (liệt kê tất cả các trường hợp)
# Inference rules (luật suy luận):
# Conversion to the inverse SAT problem (Resolution refutation)
#
# # Proof by Resolution (luật hợp giải)
#
# # Convert to CNF (Conjunctive Normal Form) chuyển từ A => B thành !A v B
