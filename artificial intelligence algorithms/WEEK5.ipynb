# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Local search algorithms
# # Hill-climbing search (greedy local search)
# Hay bị kẹt tại cực trị địa phương
# Tìm kiếm láng giềng có trạng thái tốt hơn trạng thái hiện tại
# Stochastic hill climbing (tìm trạng thái láng giềng lớn hơn - chưa chắc là chọn cái lớn nhất)
#
# # simulated annealing (luyện thép). tăng giảm nhiệt độ
# Chấp nhận trường hợp xấu hơn để có thể đạt được trạng thái tốt hơn.
#
# # Local beam search
