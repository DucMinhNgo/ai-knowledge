# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Để dùng luật hợp giải thì cần phải đưa các câu về dạng CNF (không có dấu kéo theo, tương đương, không có các vị từ với mọi, tồn tại).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Hướng dẫn về bài lab
