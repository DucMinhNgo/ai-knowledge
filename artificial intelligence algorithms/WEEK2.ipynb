# %% [markdown]
# Fully observable:
# Partially observable:
# Unobservable:
#
# Để xem xét đối tượng có phải là agent hay không thì hãy quan sát sự ảnh hưởng của mình đối với đối tượng đó.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Resolving problems by researching
# Search là quá trình quan sát chuỗi những biến đổi trạng thái để đến được đích (chuỗi những biến đổi trạng thái)
#
# Tree Search
# Graph Search (tốn nhiều chi phí hơn tree search).
