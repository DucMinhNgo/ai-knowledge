# %% [markdown]
# # Heuristic search (tìm kiếm mù).
#
# # Best first search
#     + Greedy best-first search: chọn những node có heuristic nhỏ nhất: chạy thẳng về hướng đích (nhưng không tìm ra lời giải tối ưu).
#
# # A* search: f(x) = g(x) + h(x): độ phức tạp lớn nên chạy chậm
#
# # A* Graph Search Gone Wrong
#
# # Heuristic function (làm thế nào để tìm được hàm heuristic):
#
#
# Note: Admissible (có thể chấp nhận được).
# Admissible (cái ước lượng nhỏ hơn hoặc bằng thực tế).
# - Tree Search (không duyệt lại)
# - Graph Search (có duyệt lại node)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
