# %% [markdown]
# # Vector <T> Chỉ có trong C++ ko có trong C.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Con trỏ thì kích thước của nó sẽ là 4 hoặc là bội của 4
# a[2] <=> *(a+2)
# &a[2] <=> (a+2)
#
# *& c: giống như con trỏ cấp 2 với cú pháp của con trỏ cấp 1
