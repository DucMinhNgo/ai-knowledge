# %% [markdown]
# # Struct
# - Khi không có con trỏ thì có thể gán trực tiếp, khi có con trỏ thì không được gán.
# - Mảng tỉnh thì địa chỉ của con trỏ sẽ bị ẩn đi.

# %% [markdown]
# ![image.png](attachment:image.png)
