# %% [markdown]
# # Content
# visual studio 2022
#
# Midterm: 25%
# Assignments: 25% (nhóm)
# Final: 50%
#
# Compiler: biên dịch (từ đầu đến cuối)
# Interpreter: thông dịch (thông dịch từng dòng)
#
# printf -> printf_s
#
# đối với hàm toán học thì kiểu dữ liệu là double (số thực) (%lf)
# hàm căn bậc 2 sqrt()
#
# Note: trong C kiểu char và int tương đồng nhau
#
# Khi bị tràn số thì sẽ quay lại từ 0 (dạng mod)
#
# # Kiến trúc máy tính (xử lý số)
# A << 1 ví dự A = 10 => 20 (nhanh hơn)
#
# # Đối với C không có kiểu bool chỉ tồn tại trong C++
# char
# wchar_t = L'a'; (2 byte)
#
# a = b++ (b=5 => b=6, a=5)
# a = ++b (b=5 => b=6, a=6)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Name1_Name2.cpp
