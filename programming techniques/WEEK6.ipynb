# %% [markdown]
# # Đọc file
# - Đọc theo từng ký tự
# - Đọc từng dòng
#
# stdout: in ra màn hình console.
# r+b: vừa đọc vừa ghi.
#
# fscanf: khoảng trắng sẽ dừng
# fgets: \n dừng

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Đọc dữ liệu từ file vào trong ma trận
# notepad + ascii
# tính tổng các số nguyên tố trong ma trận
# ghi tổng vào 1 file mới
