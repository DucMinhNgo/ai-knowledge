# %% [markdown]
# # Smart contract:
# - Mỗi giao dịch đều phải tốn phí để chống tấn công
# - Dữ liệu trên các node càng nhỏ càng tốt
#
# Web3.js + ether.js liên kết với mạng block chain.
# Dữ liệu lớn thì nên được lưu trữ bằng IPFS, SWARM: off-chain.
#
# # Mạng bock vhain (giả lập): ethereum
# Mạng ảo với nodejs:
# https://www.npmjs.com/package/ganache
#
#
# Cài đặt metamask extension
#
# - Dapp (dêcntralize application)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
