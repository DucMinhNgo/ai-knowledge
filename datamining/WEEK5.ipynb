# %% [markdown]
# # Đánh giá mô hình
# - confusion matrix:
#   + accuracy, error.
# - const matrix:
# - weighted matrix:
#
# # Tính toán chi phí phân lớp:
# # Độ đo
# - precision (dự đoán khả năng đúng của model): precision cao thì thường kéo theo recall thấp
# - recall
# - F-measure (F1 score: trung hòa độ lệch của precision và recall).
#
# # Làm thế nào để đánh giá hiệu suất của mô hình.
# - Đánh giá
#   + Cross - Validation:
#     - Holdout (độ chính xác không cao: thường thì không sử dụng): thường lấy 2/3 để train.
#     - Leave one out (thông thường trong thực tế không thể thực hiện được vì chi phí quá lớn)
#     - K fold (chia dữ liệu thành k phần bằng nhau): lỗi bằng trung bình cộng của k lần chạy:
#       Thường lấy k = 10 nếu dữ liệu lớn thì lấy k = 3.
#   + Bootstrap:
#     -
#   - Lý do phải đánh giá:
#     + Lựa chọn mô hình tốt nhất để giải quyết bài toán: thường chọn những phương pháp có độ lỗi thấp nhất.
#     + Ước lượng hiệu suất của mô hình.
#
# - Kiểm thử
#   + Hausdoff (đánh giá sai số tập kết quả và tập dataset):
#     - Lấy min khoảng cách từ 1 điểm đến 1 tập:
#     - Lấy max của nhũng min khoảng cách giữa từng điểm đến tập còn lại:
# ![image.png](attachment:image.png)

# %% [markdown]
# - Dữ liệu thường được chia làm 3 phần:
#   + Tập huấn luyện.
#   + kiếm tra.
#   + đánh giá.
#
# # Đường cong ROC
