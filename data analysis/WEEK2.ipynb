# %% [markdown]
# # Đồ thị tính toán
# - Trong CSDL: ER.
# - Trong máy học: trực quan mô hình tính toán.
# - Phân biệt mạng: Neron và mạng Bias.
# - Biến có hai dạng:
#   + deterministic: xác định
#   + stochastic: ngẫu nhiên
# - # Tính đạo hàm từng phần gradient

# %% [markdown]
# https://colab.research.google.com/drive/1A46kZg2eqVba-lZEoRoknA_T7LdYvxvD?authuser=2#scrollTo=pOnYeeXSucBV
# ![image.png](attachment:image.png)

# %% [markdown]
# # Vector, Tensor
# - Tensor: là một mảng nhiều chiều.
#   + Số (tensor 0 chiều)
#   + Vector (tensor 1 chiều)
