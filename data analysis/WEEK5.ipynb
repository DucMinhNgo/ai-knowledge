# %% [markdown]
# # Tiếp tục phân tích dữ liệu bằng phương pháp thông skee (93)
# - Có thể mô tả dữ liệu bằng các đại lượng mô tả, mean, phương sai, mediun.
# + Phân tích 1 biến.
# + Phân tích 2 hay nhiều biến.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Ước lượng ra khoảng tin cậy
# - Biến ngẫu nhiên:
#   + Mean
#   + Median
#   + Phương sai
#
# - Ước lượng điểm
# - Khoảng tin cậy
# - Phương pháp thường được sử dụng phổ biến maximum likelihood.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Ước lượng điểm:

# %% [markdown]
# # Bài tập
# ![image.png](attachment:image.png)

# %%
Giải:

# %% [markdown]
# # Nhắc lại kiến thức hồi quy tuyến tính ở góc nhìn thống kê
# - Ước lượng tham số MSE (Mean of squard error): đường hồi quy (duy nhất).
# - MAE (có vô số đường).

# %% [markdown]
# # Phần mềm vẽ đồ thị
# https://www.geogebra.org/classic?lang=vi
#
# python dùng stats mode
# trong thống kê sử dụng ols của stats mode
# https://www.statsmodels.org/stable/index.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Làm 3, 4, 5, 6 stats mode
# https://colab.research.google.com/drive/1L-5DzIUJe3XRGkhFVOyLTj_Q0HT3hbot?authuser=2

# %% [markdown]
# ![image.png](attachment:image.png)là bằng notebook (export ra pdf).
#
# # Làm bài tập nộp lên moodle (7.4)
# # Tìm hiểu lý thuyết
