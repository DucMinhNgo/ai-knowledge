# %% [markdown]
# # Thinking in Frequency (biến đổi về miền tần số).
# - Thay vì truyền dữ liệu gốc thì truyền chỉ số hoặc số liệu mang tính sấp xỉ (hàm sin). (a(biên độ, scale)*w(t) + phi (lệch pha: dời)): Biến đổi Fourier (đọc thêm), biến đổi wavelet: Phân tích biến đổi ngược, decompose (phân rã) và reconstructure (tổng hợp lại).
# - Histograms àn color balancings. (soft (hard) assignment).
#     + Histogram equalization (phân bố đề hết).
#     + Histogram specification (kì vọng trong khoảng).
# - Cắt ghép ảnh.
#     - Graph cuts
#     - lazy snapping
#     - Poisson Blending (bản chất không cắt dán hình mà cắt dán vector gradient: giữ lại vector gradient, không phải giữ lại màu): bóng có thể bị sai.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # highlight text information automatically
# # Trộn ảnh với Fourier.
# # Dự đoán giá
