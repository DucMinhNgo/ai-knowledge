# %% [markdown]
# # Image Ballistic
# - Tìm kiếm hình ảnh đã được up lên mạng hay chưa?
# - Filename Inspection.
#
# # Cheap Fake (Ảnh thật nhưng nội dung bài viết bị thay đổi, hoặc đăng ở vị trí khác với nội dung khác), Deep Fake (thay đổi hình ảnh)
# - COSMOS baseline.

# %% [markdown]
# # Gioi thiệu một số chủ đề về đồ án cuối kỳ
# - Nhóm 1-2 sinh viên.
# - Chỉ nộp báo cáo không thi tự luận, không vấn đáp, ko báo cáo.
# - Một số chủ đề gợi ý:
#     + Cross image (ghép ảnh).
#     + Tô màu ảnh manga.
#     + sketch: vẽ 1 con hoạt hình cho nó tự động chạy.
#     + Viết truyện tranh tự động: generate ra một kịch bản cụ thể.
#     + Khôi phục lại ảnh của 1 công trình bị hư hỏng. Phác thảo lại.
#     + Xây dựng đối tượng 3D của đối tượng trong hình ảnh. Motion capture.
#     + Tìm kiếm gì đó trong bức hình (image retrival).
#     + Ứng dụng tự tạo dữ liệu, và tự tạo model (cháy rừng).
#     + Monalisa đang nói chuyện (sinh chuyển động từ hình ảnh). Sinh ảnh monalisa năm 2023. tạo ra bối cảnh xung quanh.
#     + Gần giống pokemon go.
#     + Ứng dụng đo khoảng cách.
#     + Đặt đồ vật thử trong nhà xem có vừa, hợp màu không.
#     + Ứng dụng decorator căn phòng.
#     + Ứng dụng thay đổi trang phục.
#     + Weather Change (thay đổi thời tiết). GAN.
#     + Image inpainting.
#     + Semantic Image Synthesis.
#     + Ghép 2 ảnh thành 1 ảnh mới (Neural style Transfer): Image Content, Image Style.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # GenAL - Generative Adversarial Network
# - output: Hình ảnh, ngôn ngữ, audio, video.
#
# Generator discriminator
# - styleGAN.
