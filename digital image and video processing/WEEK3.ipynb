# %% [markdown]
# # Đặc trưng màu (color moment)
# # Lược đồ liên kết màu
#
# # Đặc trưng dáng
# Dáng là tập hợp các điểm mà tại đó có sự biến thiên lớn về màu sắc => tìm được 1 cái đại lượng mà mô phỏng bản chất về dáng.
#
# Ảnh biên độ e(x, y) => threadhole (BEI: Binary Edge Image)
#
# Cùng một đặc trưng mà có nhiều ngữ nghĩa thì gọi là tính đa nghĩa.
#
# # Lược đồ hệ số góc
#
#
# # ??? Bài tập tại sao lại phải sử dụng phần tử cuối cùng H(72) để tính lược đồ hệ số góc.
# # ??? Viết giải thuật chia lược đồ ảnh biên cạnh, và tách thành lược đồ ảnh bên cạnh liên kết và lược đồ ảnh biên cạnh khôgn liên kết
#
# View, Scale, light (góc nhìn, xa gần, đồ chiếu sáng) là ba yếu tố quan trọng hàng đầu để đánh giá đặc trưng.

# %% [markdown]
# # Giải thuật tính lược đồ ảnh biên cạnh (cập nhật thêm và hoàn thiện)
# Begin:
# m(Id, i)
# a = []
# neID = 0
# nID = 0
#
# For each pixel in image:
#     e
#     alpha
#     nEdge = 0
#
#     if i > T:
#         nEdge += 1
#
# End:

# %% [markdown]
# # Giải thuật tách ảnh biên cạnh
# Input: Tập điểm biên cạnh (mảng hai chiều): giả sử ED[][] là tập ảnh biên cạnh
# Output: Lược đồ liên kết (ED_link[][]), Lược đồ không liên kết ảnh (ED_nolink[][])
# Begin
#     ED_nolink (mảng hai chiều)
#     ED_link (mảng hai chiều)
#     # giả sử (bin 3x3)
#     for r in row(ED):
#         for c in column(ED):
#             # Xét trên ma trận 3x3 (nếu >: 0.1% số điểm trên ảnh thì đưa về mảng ED liên kết, ngược lại đưa về ED không liên kết)
#             sum = 0;
#             for r1 in [row(r-1), row(r+1)]:
#                 for c1 in [column(c-1), column(c+1)]:
#                     if distance(ED(r,c), ED(r1, c1)) < T:
#                         sum += 1
#
#             if (sum >= 0.1*n(ED)):
#                ED_link.push(ED(r, c))
#             else:
#                 ED_nolink.push(ED(r, c))
# End

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
