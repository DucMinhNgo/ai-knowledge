# %% [markdown]
# # 12.
# - Giải thích xem tích vô hướng có ý nghĩa gì
#     + ??? Phép nhân ma trận được hiểu và cái gì (nhân là tính core relation: học dựa trên sự tương quan giữa ảnh và text):
#         - ??? sự tương quan đó có ý nghĩa gì: tìm đc bộ tham số để mã hóa thành các tensor tìm ẩn (phải giữ lại đc bản chất, ngữ nghĩa của gốc), giữ lại đc ngữ nghĩa (semantic)
#     + ??? Phép cộng trong ma trận được hiểu là cái gì
#     + ??? tại sao zero shot: lại có thể dùng mà ko phải fine turning để đạt đc hiệu xuất cao:
#         - Do mô hình đã hiểu được ngữ cảnh (mơ hồ)
#     + ??? 1 mô hình dùng đc cho nhiều task
#     + ??? Khả năng tổng quát hóa cao

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Phương pháp
